# %%
# question2.a

from sklearn.decomposition import TruncatedSVD
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from numpy import linalg as LA
plt.style.use('classic')
img = Image.open('Japan_flag.png')
from numpy.linalg import matrix_rank

# %%
# convert image to grayscale
imggray = img.convert('LA')
# convert to numpy array
imgmat = np.array(list(imggray.getdata(band=0)), float)
# Reshape according to orginal image dimensions
imgmat.shape = (imggray.size[1], imggray.size[0])
plt.figure(figsize=(9, 6))
plt.imshow(imgmat, cmap='gray')
plt.show()

# %%
#2.b

U, D, V = np.linalg.svd(imgmat)

# %%
print("imgmat=",imgmat)
print("U=",U)
print("D=",D)
print("V",V)
# Out:
# imgmat= [[255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  ...
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]
#  [255. 255. 255. ... 255. 255. 255.]]
# U= [[-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ...  7.62976228e-18
#   -1.22601407e-17  1.72141594e-18]
#  [-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ...  6.76797856e-19
#    1.29617676e-18 -9.32093547e-19]
#  [-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ... -2.92737025e-18
#    3.47311645e-18 -1.98709830e-18]
#  ...
#  [-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ... -4.56334127e-17
#    1.06833280e-16 -5.26365327e-17]
#  [-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ...  4.29422485e-17
#   -1.12931069e-16  5.35934377e-17]
#  [-8.22714953e-02 -7.57364220e-02 -2.58791176e-02 ...  2.75684770e-18
#   -5.53542972e-19  1.45349216e-19]]
# D= [5.04503438e+04 1.05711259e+04 4.15425618e+03 2.42958430e+03
# ...

# %%
print(imgmat.shape)
print(U.shape)
print(D.shape)
print(V.shape)
# Out:
# (183, 275)
# (183, 183)
# (183,)
# (275, 275)

# %%
#2.c
s=imgmat.shape[0]
for k in range(1,s):
    Ak= np.dot(U[:,:k],np.dot(np.diag(D[:k]),V[:k,:]))
    print("Ak",k,)
    print(Ak)
# Out:
# Ak 1
# [[282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]
#  [282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]
#  [282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]
#  ...
#  [282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]
#  [282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]
#  [282.1292499 282.1292499 282.1292499 ... 282.1292499 282.1292499
#   282.1292499]]
# Ak 2
# [[254.03884275 254.03884275 254.03884275 ... 254.03884275 254.03884275
#   254.03884275]
#  [254.03884275 254.03884275 254.03884275 ... 254.03884275 254.03884275
#   254.03884275]
#  [254.03884275 254.03884275 254.03884275 ... 254.03884275 254.03884275
#   254.03884275]
#  ...
#  [254.03884275 254.03884275 254.03884275 ... 254.03884275 254.03884275
#   254.03884275]
#  [254.03884275 254.03884275 254.03884275 ... 254.03884275 254.03884275
#   254.03884275]
# ...

# %%
#2.d
def RelativeError(A,Ak):
    dif=np.subtract(A,Ak)
    error=(LA.norm(dif))/LA.norm(A)
    return error*100

# %%
#2.e
E=[]
A=imgmat
count=0
for k in range(1,s):
    Ak= np.dot(U[:,:k],np.dot(np.diag(D[:k]),V[:k,:]))
    RE=RelativeError(A,Ak)
    E.append(RE)  
    if(RE<1 and count==0):
        count=count+1
        print(k)
# Out:
# 26

# %%
E
# Out:
# [23.20762844534179,
#  11.09913274754806,
#  7.68363140054119,
#  6.090601452982406,
#  5.126590657617021,
#  4.455029177389917,
#  3.953943013560017,
#  3.558626597340079,
#  3.2350012210313674,
#  2.961665430872905,
#  2.7260650582074804,
#  2.52265588918432,
#  2.3397474120397783,
#  2.177051894386512,
#  2.0282451705965,
#  1.8929766512002653,
#  1.7690493858506455,
#  1.6529334288363113,
#  1.5449485919372414,
#  1.444350574083703,
#  1.3476709712369084,
#  1.2562986508553167,
#  1.1713107926731525,
#  1.0891843434131692,
#  1.0074524240895715,
#  0.9266427897374079,
#  0.8493477357418446,
#  0.7747798034620348,
#  0.7025530295715785,
#  0.6269964661012131,
#  0.5417613838628854,
#  0.4496595949736111,
#  0.3592570315904945,
#  0.24023582577508662,
#  0.013965686265379336,
#  0.01191608362053901,
#  0.009638501919854653,
#  0.00808607556523075,
#  0.006340516526556607,
#  0.005118721001759445,
#  0.0037644446048581007,
#  0.0024149841798319647,
#  0.0011635522234037653,
# ...

# %%
plt.plot(E)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#Ak plot when error is first less than 1%
k=26
Ak= np.dot(U[:,:k],np.dot(np.diag(D[:k]),V[:k,:]))
# Reshape according to orginal image dimensions
plt.imshow(Ak, cmap='gray')
plt.show()
plt.imshow(imgmat, cmap='gray')
plt.show()

# %%
matrix_rank(imgmat)
# Out:
# 45

# %% [markdown]
#  For US Flag relative error is less than for k=65 and for japan flag relative error is less than 1% when k=26 and error
# becomes close to zero at higher values of k in US flag than japan flag.  It can be said that US flag as more data when
# compared to japan flag. when ranks are caluclated for both the flags US flag as rank of 174 and japan flag as a rank of 45.
# so it is verified that US flag as more data than Japan flag.
